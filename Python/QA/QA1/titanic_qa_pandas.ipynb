# %% [markdown]
# #### Performing visual analysis on the Titanic survivors using the built-in seaborn Titanic dataset.

# %%
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names() # gives list of built-in datasets
df = sns.load_dataset("titanic")
df.tail(20)
# survived: 0 for no, 1 for yes
# pclass: passanger class, 1 (wealthy), 2(middle-class), 3(immigrants)
# sibsp: num of siblings/spouses on board
# embarked: port where they got on, first letter of town name
# deck: cabin location, A-C housed 1st class, D-E housed all classes, F-G housed second and third classes
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# ...

# %%
lowest_fare = df["fare"].min()
lowest_fare
# Out:
# np.float64(0.0)

# %% [markdown]
# ##### Is survived the same as survivors?

# %%
survivors = df["alive"].value_counts()
survivors
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
survived = df["survived"].value_counts()
survived
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.shape
# 891 rows, 15 columns
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %% [markdown]
# ##### Questions from our Exploratory Data Analysis (EDA)
# * Is there any bias in who survives?
#     * Male/Female
#     * Class (Wealthy vs Poor)
#     * Age (Children priotized?)
#     * Siblings/Spouse on board
# * What type of graphics would be best?
#     * Scatter-plot (good for wholistic visuals)
#     * Histograms (good to see distribution, patterns)
