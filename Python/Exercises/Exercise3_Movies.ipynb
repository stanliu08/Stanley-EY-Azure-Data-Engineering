# %% [markdown]
# # EDA And Data Profiling with Pandas

# %% [markdown]
# Given your movie dataset, perform the following tasks: <br/>
# - Load the dataset into a Pandas DataFrame.
# - Perform exploratory data analysis (EDA) to understand the structure and content of the dataset.
# - Clean the data:
#     - Handle missing values
#     - Remove any duplicates
#     - Correct data types if necessary
#     - Determine how to handle any outliers
#     - Determine which columns have little to no analytical worth and drop them
# <br/>
#
# Answer the following questions based on your cleaned dataframe:
# 1. How many unique genres exist in the dataset?
#     - 23
#     1. What are the top 5 most common genres?
#     - 1. Drama : 726,
#     - 2. Comedy : 289,
#     - 3. Thriller : 229,
#     - 4. Adventure : 206,
#     - 5. Romance : 206
# 2. What is the newest movie in the dataset? The oldest?
#     - Newest: Chak De! India
#     - Oldest: The Cabinet of Dr. Caligari
# 3. What are the top 10 highest-rated movies (by IMDb rating)?
#
#     1. The Godfather Trilogy: 1901-1980           | 9.3
#     2. The Shawshank Redemption                    | 9.3
#     3. The Godfather                               | 9.2
#     4. The Chaos Class                             | 9.2
#     5. The Dark Knight                             | 9.1
#     6. Schindler's List                            | 9.0
#     7. CM101MMXI Fundamentals                      | 9.0
#     8. 12 Angry Men                                | 9.0
#     9. The Godfather Part II                       | 9.0
#     10. The Lord of the Rings: The Return of the King | 9.0
#
# 4. What is the distribution of IMDb ratings (mean, median, standard deviation)?
#     - Mean: 7.84
#     - Median: 7.90
#     - Standard Deviation: 0.4678
# 5. How do average IMDb ratings vary by genre?
#
# - Documentary    8.027273
# - Film-Noir      7.988889
# - War            7.952500
# - Animation      7.940299
# - Sport          7.916000
# - Biography      7.893069
# - Mystery        7.892500
# - Crime          7.883417
# - History        7.877049
# - Drama          7.873416
# - Short          7.860000
# - Family         7.853409
# - Fantasy        7.850000
# - Western        7.840000
# - Thriller       7.824454
# - Adventure      7.821359
# - Sci-Fi         7.790833
# - Action         7.773370
# - Music          7.758824
# - Musical        7.758537
# - Romance        7.715534
# - Comedy         7.704844
# - Horror         7.680488
#
# 6. What director has the most movies in the dataset?
#  - Alfred Hitchcock with 13 movies
# 7. Is there a relationship between the Meta_score and IMDB_Rating? (if applicable)
# - N/A
# 8. What stars appear most frequently in the dataset? (if applicable)
# - N/A
# 9. Average Runtime per year (if applicable)
# - Answer located where code is
# 10. Shortest movie for each genre (if applicable)
# - Answer located where code is
# 11. Longest movie for each genre (if applicable)
# - Answer located where code is

# %% [markdown]
# > **Note**
# > You will not be turning in this exercise. <br/>
# > However, you will be using this in a group activity tomorrow.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Step 1: Load and clean data

# %%
# load data
fpath = r"C:\Users\stanl\20251124-EY-Azure-Data-Engineering\Python\Data\Movie Data\imdb-top-rated-movies-user-rated-kaggle.csv"
# skips the very first row with the bad data
df = pd.read_csv(fpath, skiprows= 1)
# made copy just in case we want old values
movies = df.copy()
# movies.head()

# %%
# gets sum of all empty values
movies.isna().sum()
# Out:
# Position          0
# Title             0
# Original Title    0
# URL               0
# Title Type        0
# IMDb Rating       0
# Runtime (mins)    0
# Year              0
# Genres            0
# Num Votes         0
# Release Date      1
# Directors         4
# dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 993 entries, 0 to 992
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Position        993 non-null    int64
#  1   Title           993 non-null    object
#  2   Original Title  993 non-null    object
#  3   URL             993 non-null    object
#  4   Title Type      993 non-null    object
#  5   IMDb Rating     993 non-null    float64
#  6   Runtime (mins)  993 non-null    int64
#  7   Year            993 non-null    int64
#  8   Genres          993 non-null    object
#  9   Num Votes       993 non-null    int64
#  10  Release Date    992 non-null    object
#  11  Directors       989 non-null    object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 93.2+ KB

# %%
movies[movies["Directors"].isna()]
# replaces empty values in Directors with string Unknown
movies["Directors"] = movies["Directors"].fillna("Unknown")

# %%
# don't know how to replace NaN in date time format, will leave blank for now
movies[movies["Release Date"].isna()]
# Out:
#      Position                                 Title  \
# 892       893  Playboy: The Best of Pamela Anderson
#
#                            Original Title  \
# 892  Playboy: The Best of Pamela Anderson
#
#                                        URL Title Type  IMDb Rating  \
# 892  https://www.imdb.com/title/tt0112482/      Video          6.3
#
#      Runtime (mins)  Year       Genres  Num Votes Release Date  \
# 892              54  1995  Documentary       1493          NaN
#
#                                              Directors
# 892  Vicangelo Bulluck, Scott Allen, Andrew Blake, ...

# %%
# I don't think Original Title or URL has much use, we will drop it
movies.drop(columns=["Original Title", "URL", "Title Type"], inplace=True)

# What is Position based off? Maybe I will drop it too?
# movies.drop(columns="Position", inplace = True)

# %%
movies.head()
# Out:
#    Position                     Title  IMDb Rating  Runtime (mins)  Year  \
# 0         1  The Shawshank Redemption          9.3             142  1994
# 1         2             The Godfather          9.2             175  1972
# 2         3                 12th Fail          8.7             147  2023
# 3         4     The Godfather Part II          9.0             202  1974
# 4         5           The Dark Knight          9.1             152  2008
#
#                            Genres  Num Votes Release Date  \
# 0                           Drama    3127837   10/14/1994
# 1                    Crime, Drama    2182281    3/24/1972
# 2                Biography, Drama     163253   10/27/2023
# 3                    Crime, Drama    1467166   12/18/1974
# 4  Action, Crime, Drama, Thriller    3103433    7/18/2008
#
#               Directors
# 0        Frank Darabont
# 1  Francis Ford Coppola
# 2    Vidhu Vinod Chopra
# 3  Francis Ford Coppola
# 4     Christopher Nolan

# %% [markdown]
# ### Dataframe is now cleaned
# ### Answers to questions

# %% [markdown]
# ##### 1. How many unique genres exist in the dataset?
# ##### Answer: 23
# #####    1. What are the top 5 most common genres?
# ##### Answer: 1. Drama : 726, 2. Comedy : 289, 3. Thriller : 229, 4. Adventure : 206, 5. Romance : 206

# %%
# some shows have multiple genres
movies["Genres"].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Biography, Drama',
#        'Action, Crime, Drama, Thriller', 'Biography, Drama, History',
#        'Adventure, Drama, Fantasy', 'Adventure, Drama, Western',
#        'Action, Adventure, Fantasy, Sci-Fi',
#        'Action, Adventure, Sci-Fi, Thriller', 'Crime, Drama, Thriller',
#        'Action, Adventure, Drama, Sci-Fi', 'Action, Drama',
#        'Animation, Action, Adventure, Family, Fantasy, Sci-Fi',
#        'Biography, Crime, Drama', 'Action, Sci-Fi',
#        'Crime, Drama, Horror, Thriller', 'Drama, Romance',
#        'Drama, Romance, War', 'Crime, Drama, Mystery, Thriller',
#        'Drama, Family, Fantasy, Romance', 'Action, Adventure',
#        'Drama, Horror, Mystery, Thriller', 'Drama, Mystery, Thriller',
#        'Drama, Western', 'Adventure, Drama, Sci-Fi', 'Drama, Music',
#        'Documentary, Comedy', 'Drama, Thriller', 'Drama, War',
#        'Comedy, War', 'Comedy, Drama', 'Drama, Film-Noir',
#        'Drama, Mystery, War', 'Comedy, Drama, Romance, War',
#        'Biography, Drama, Music, War',
#        'Animation, Adventure, Family, Fantasy', 'Comedy, Drama, Romance',
#        'Drama, Mystery', 'Action, Adventure, Sci-Fi',
#        'Drama, Mystery, Sci-Fi, Thriller', 'Horror, Sci-Fi',
#        'Animation, Adventure, Family, Sci-Fi',
#        'Adventure, Drama, Mystery, Thriller', 'Drama, Horror',
#        'Crime, Drama, Fantasy, Mystery', 'Adventure, Comedy, Sci-Fi',
#        'Mystery, Romance, Thriller', 'Adventure, Biography, Drama, War',
#        'Comedy, Romance', 'Action, Adventure, Drama',
#        'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama, Family, Musical',
#        'Action, Adventure, Horror, Sci-Fi, Thriller',
#        'Drama, Romance, Sci-Fi',
#        'Animation, Adventure, Comedy, Family, Fantasy',
#        'Comedy, Drama, Romance, Sci-Fi', 'Comedy, Drama, War',
#        'Crime, Sci-Fi',
#        'Animation, Adventure, Drama, Family, Fantasy, Music, Mystery',
#        'Crime, Thriller', 'Crime, Drama, Film-Noir, Mystery, Thriller',
#        'Adventure, Drama, War', 'Animation, Drama, Fantasy, Romance',
#        'Action, Adventure, Drama, Horror, Sci-Fi', 'Comedy, Music',
#        'Action, Drama, Mystery, Thriller',
#        'Documentary, Biography, Sport',
#        'Biography, Drama, History, Musical', 'Biography, Drama, Music',
#        'Adventure, Sci-Fi', 'Comedy, Musical, Romance',
#        'Animation, Adventure, Fantasy', 'Biography, Drama, War',
#        'Adventure, Comedy, Fantasy', 'Animation, Drama, War',
#        'Drama, Film-Noir, Mystery, Thriller',
#        'Action, Biography, Drama, Sport', 'Comedy, Crime, Drama',
#        'Crime, Drama, Mystery', 'Comedy, Music, Romance', 'Drama, Sci-Fi',
#        'Biography, Drama, History, War', 'Drama, Fantasy, War',
#        'Drama, Family', 'Biography, Drama, Sport',
#        'Animation, Short, Comedy, Crime, Family, Mystery, Sci-Fi',
#        'Animation, Adventure, Comedy, Drama, Family',
#        'Action, Drama, History, Thriller, War', 'Comedy, Drama, Music',
#        'Animation, Action, Adventure, Family, Sci-Fi',
#        'Crime, Drama, Film-Noir, Mystery, Romance',
#        'Adventure, Drama, Thriller, War', 'Action, Drama, War',
#        'Action, Crime, Drama, Mystery, Thriller', 'Comedy, Drama, Family',
#        'Adventure, Comedy, Crime, Drama',
#        'Documentary, Biography, Crime, History', 'Comedy, Drama, Fantasy',
#        'Biography, Comedy, Drama, Music', 'Action, Drama, Thriller',
#        'Action, Thriller', 'Drama, Fantasy', 'Drama, Sci-Fi, Thriller',
#        'Drama, Family, Sport', 'Drama, Mystery, Sci-Fi', 'Comedy, Crime',
#        'Drama, Thriller, War', 'Biography, Comedy, Crime, Drama',
#        'Action, Drama, Sci-Fi, Thriller',
#        'Crime, Drama, Film-Noir, Thriller', 'Crime, Drama, Romance',
#        'Animation, Comedy, Family, Fantasy, Musical',
#        'Action, Crime, Drama', 'Comedy',
#        'Drama, Mystery, Romance, Thriller',
#        'Animation, Adventure, Comedy, Drama, Family, Fantasy',
#        'Drama, Musical', 'Action, Adventure, Comedy, Drama, War',
#        'Action, Crime, Thriller', 'Comedy, History',
#        'Adventure, Horror, Thriller', 'Drama, Thriller, Western',
#        'Biography, Drama, Mystery', 'Drama, Sport',
#        'Biography, Crime, Drama, History',
#        'Comedy, Drama, Music, Musical, Romance',
#        'Action, Drama, Mystery, Sci-Fi, Thriller',
#        'Action, Sci-Fi, Thriller', 'Action, Drama, Sport',
#        'Drama, History', 'Action, Crime, Drama, Music',
#        'Action, Adventure, Comedy, Drama, Fantasy, Sci-Fi',
#        'Drama, History, War', 'Adventure, Family, Fantasy, Musical',
#        'Drama, Film-Noir, Mystery, Romance, Thriller',
#        'Adventure, Comedy, Drama, Romance, Western',
#        'Animation, Adventure, Comedy, Family',
#        'Adventure, Drama, Thriller', 'Action, Comedy, Romance',
#        'Action, Comedy, Sci-Fi',
#        'Biography, Crime, Drama, History, Thriller',
#        'Action, Adventure, Comedy, Sci-Fi', 'Adventure, Biography, Drama',
#        'Animation, Action, Adventure, Family, Fantasy',
#        'Adventure, Comedy, Fantasy, Mystery', 'Comedy, Drama, Thriller',
#        'Adventure, Drama', 'Horror, Mystery, Sci-Fi', 'Horror, Thriller',
#        'Animation, Comedy, Drama',
#        'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#        'Action, Adventure, Thriller', 'Action, Mystery, Thriller',
#        'Comedy, Drama, Fantasy, Horror, Mystery, Sci-Fi, Thriller',
#        'Biography, Drama, Family', 'Adventure, Fantasy',
#        'Animation, Action, Adventure, Comedy, Family, Fantasy, Sci-Fi',
#        'Drama, Music, Romance',
#        'Adventure, Biography, Crime, Drama, Western',
#        'Animation, Adventure, Comedy', 'Action, Comedy, Horror',
#        'Animation, Action, Adventure, Comedy, Family, Fantasy',
#        'Action, Adventure, Drama, Sci-Fi, Thriller',
#        'Adventure, Comedy, Drama',
#        'Adventure, Comedy, Family, Fantasy, Romance',
#        'Action, Adventure, Drama, Fantasy, Romance',
#        'Animation, Action, Adventure, Family',
#        'Crime, Drama, Horror, Mystery, Thriller', 'Action, Comedy, Crime',
#        'Action, Adventure, Comedy, Crime, Drama, Musical, Thriller',
#        'Action, Comedy, Crime, Drama',
#        'Animation, Action, Adventure, Comedy, Crime, Family, Mystery',
#        'Animation, Action, Adventure, Comedy, Family, Sci-Fi, Thriller',
#        'Comedy, Drama, Music, Romance',
#        'Drama, Horror, Musical, Thriller', 'Drama, Fantasy, Romance',
#        'Comedy, Fantasy, Horror',
#        'Adventure, Comedy, Drama, Fantasy, Romance',
#        'Action, Adventure, Fantasy, Sci-Fi, War',
#        'Action, Drama, Mystery, Sci-Fi', 'Animation, Adventure, Sci-Fi',
#        'Adventure, Family, Fantasy, Mystery',
#        'Biography, Drama, Family, Musical, Romance',
#        'Action, Adventure, Drama, History, War',
#        'Animation, Drama, Family, Fantasy',
#        'Biography, Drama, History, Thriller', 'Drama, Romance, Thriller',
#        'Animation, Adventure, Comedy, Drama, Family, Fantasy, Music',
#        'Comedy, Romance, War', 'Comedy, Musical',
#        'Comedy, Crime, Drama, Fantasy',
#        'Animation, Action, Drama, Sci-Fi', 'Mystery, Sci-Fi, Thriller',
#        'Biography, Crime, Drama, Thriller', 'Drama, Musical, Sport',
#        'Action, Comedy, Mystery, Thriller',
#        'Action, Comedy, Crime, Drama, Thriller',
#        'Biography, Drama, Thriller, War', 'Animation, Drama',
#        'Animation, Action, Adventure, Fantasy, Thriller',
#        'Adventure, Drama, Romance, War',
#        'Action, Adventure, Mystery, Sci-Fi, Thriller',
#        'Comedy, Drama, Fantasy, Romance', 'Biography, Comedy, Drama',
#        'Drama, Horror, Thriller', 'Comedy, Family, Romance',
#        'Animation, Action, Adventure, Comedy, Drama, Family, Sci-Fi',
#        'Action, Adventure, Drama, Western',
#        'Action, Comedy, Romance, Thriller', 'Comedy, Drama, Fantasy, War',
#        'Comedy, Crime, Drama, Thriller',
#        'Drama, Fantasy, Horror, Romance',
#        'Action, Adventure, Family, Fantasy, Mystery',
#        'Action, Biography, Drama, History, War',
#        'Documentary, Animation, Biography, Drama, History, Mystery, War',
#        'Action, Comedy, Fantasy, Romance',
#        'Action, Biography, Drama, War',
#        'Adventure, Drama, Family, Fantasy, Mystery', 'Mystery, Thriller',
#        'Documentary, Crime', 'Comedy, Drama, Musical, Sci-Fi',
#        'Action, Adventure, Comedy, Thriller',
#        'Animation, Adventure, Drama, Family, Fantasy',
#        'Horror, Mystery, Thriller',
#        'Comedy, Crime, Drama, Mystery, Thriller',
#        'Drama, Fantasy, Horror, Thriller',
#        'Comedy, Drama, Musical, Romance', 'Crime, Drama, History',
#        'Animation, Adventure, Comedy, Family, Fantasy, Musical, Romance',
#        'Animation, Action, Drama, Fantasy, Sci-Fi',
#        'Action, Crime, Drama, Film-Noir, Thriller',
#        'Biography, Crime, Drama, History, Mystery, Thriller',
#        'Action, Crime, Drama, Western', 'Action, Drama, Thriller, War',
#        'Action, Adventure, Fantasy', 'Comedy, Crime, Romance', 'Horror',
#        'Adventure, Drama, Fantasy, Sci-Fi',
#        'Adventure, Drama, Fantasy, Romance',
#        'Animation, Adventure, Family, Fantasy, Musical',
#        'Comedy, Crime, Drama, Mystery, Romance',
#        'Animation, Family, Fantasy, Musical, Romance',
#        'Action, Adventure, Romance', 'Adventure, Drama, Mystery, Sci-Fi',
#        'Adventure, Drama, Mystery, Romance',
#        'Drama, Horror, Sci-Fi, Thriller', 'Drama, Mystery, Romance',
#        'Animation, Adventure, Comedy, Family, Fantasy, Romance',
#        'Comedy, Family', 'Comedy, Crime, Thriller', 'Fantasy, Horror',
#        'Animation, Short, Comedy, Crime, Family, Mystery',
#        'Biography, Comedy, Drama, Romance', 'Adventure, Western',
#        'Crime, Drama, Film-Noir, Romance, Thriller',
#        'Adventure, Biography, Drama, History, War',
#        'Action, Comedy, Crime, Thriller',
#        'Drama, Music, Musical, Romance', 'Drama, Mystery, Western',
#        'Adventure, Horror', 'Action, Biography, Crime, Drama',
#        'Drama, Horror, Sci-Fi', 'Drama, History, Thriller, War',
#        'Biography, Drama, Music, Romance',
#        'Adventure, Comedy, Drama, Music',
#        'Animation, Adventure, Comedy, Family, Fantasy, Mystery, Sci-Fi',
#        'Drama, Mystery, Romance, War',
#        'Biography, Crime, Drama, History, Western',
#        'Adventure, Fantasy, Romance', 'Comedy, Horror',
#        'Animation, Biography, Drama, History, War',
#        'Action, Comedy, Horror, Thriller',
#        'Drama, Family, History, Musical', 'Adventure, Biography, War',
#        'Documentary, Adventure, Drama, Sport',
#        'Biography, Drama, Romance, Sport',
#        'Animation, Drama, Family, Musical, Romance',
#        'Action, Drama, History, Thriller',
#        'Adventure, Comedy, Drama, Film-Noir, Romance, Thriller, War',
#        'Action, Adventure, Biography, Drama, History',
#        'Drama, Film-Noir, Mystery', 'Comedy, Music, Musical',
#        'Comedy, Mystery, Romance, Thriller', 'Short, Action, Sci-Fi',
#        'Adventure, Drama, Sport', 'Drama, History, Thriller',
#        'Adventure, Drama, Family, Western', 'Comedy, Crime, Sci-Fi',
#        'Comedy, Horror, Sci-Fi', 'Western',
#        'Drama, Fantasy, Music, Mystery, Romance',
#        'Comedy, Drama, Romance, Sport',
#        'Adventure, Biography, Drama, History',
#        'Action, Crime, Mystery, Sci-Fi, Thriller',
#        'Action, Crime, Drama, Fantasy, Horror, Thriller',
#        'Adventure, Comedy, Drama, Romance',
#        'Action, Crime, Sci-Fi, Thriller', 'Crime, Drama, Musical',
#        'Comedy, Crime, Mystery, Romance',
#        'Drama, Fantasy, Romance, Sci-Fi',
#        'Action, Drama, Mystery, Thriller, War', 'Drama, Musical, Romance',
#        'Horror, Mystery', 'Comedy, Drama, History, Romance',
#        'Comedy, Crime, Musical', 'Documentary, Music',
#        'Crime, Drama, Music, Thriller',
#        'Comedy, Fantasy, Horror, Thriller',
#        'Adventure, Comedy, Crime, Music, Musical',
#        'Adventure, Comedy, Crime, Drama, Music',
#        'Animation, Short, Adventure, Comedy, Family, Sci-Fi',
#        'Comedy, Drama, Family, Fantasy',
#        'Animation, Family, Fantasy, Music, Musical',
#        'Comedy, Drama, Romance, Thriller',
#        'Animation, Action, Crime, Drama, Mystery, Sci-Fi, Thriller',
#        'Drama, Music, Mystery, Romance', 'Thriller',
#        'Biography, Drama, History, Western',
#        'Biography, Crime, Drama, Romance', 'Action, Drama, History, War',
#        'Adventure, Comedy, Family, Fantasy, Musical',
#        'Adventure, Family, Sci-Fi', 'Crime, Drama, Romance, Thriller',
#        'Drama, Comedy',
#        'Animation, Adventure, Family, Fantasy, Musical, Romance',
#        'Drama, Horror, Mystery, Romance', 'Drama, Fantasy, Music',
#        'Documentary, Drama, Sport', 'Comedy, Horror, Musical',
#        'Drama, Family, Romance', 'Drama, Family, Fantasy',
#        'Animation, Comedy, Drama, Family, Music',
#        'Adventure, Drama, History',
#        'Action, Comedy, Crime, Romance, Thriller',
#        'Drama, Family, Musical, Romance', 'Comedy, Fantasy, Romance',
#        'Action, Crime, Horror', 'Short, Fantasy, Horror',
#        'Adventure, Family, Fantasy', 'Adventure, Drama, Romance',
#        'Documentary', 'Animation, Comedy, Fantasy, Musical',
#        'Crime, Drama, Sci-Fi, Thriller', 'Comedy, Romance, Sci-Fi',
#        'Adventure, Comedy, Drama, Fantasy',
#        'Adventure, Drama, History, War', 'Drama, Family, Fantasy, Sport',
#        'Crime, Drama, Musical, Romance',
#        'Comedy, Family, Fantasy, Musical',
#        'Comedy, Crime, Drama, Romance, Thriller',
#        'Animation, Adventure, Comedy, Family, Musical',
#        'Animation, Adventure, Comedy, Family, Fantasy, Musical, War',
#        'Comedy, Western', 'Adventure, Drama, Family, History',
#        'Animation, Adventure, Drama, Family',
#        'Animation, Adventure, Comedy, Family, Musical, Romance',
#        'Action, Adventure, Drama, Romance, War',
#        'Adventure, Crime, Drama', 'Animation, Action, Fantasy'],
#       dtype=object)

# %%
# Flattens all genres into one big list
# we also inclue "," since many strings end in it
genres_split = movies["Genres"].str.split(",")
# genres_split
# help from google
all_genres = [g.strip() for sublist in genres_split for g in sublist]
all_genres
# Out:
# ['Drama',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'History',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Western',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Drama',
#  'Action',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Sci-Fi',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Romance',
#  'War',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Western',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Music',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'War',
#  'Comedy',
#  'War',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Film-Noir',
#  'Drama',
#  'Mystery',
#  'War',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'War',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Music',
#  'War',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Mystery',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Horror',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'War',
#  'Drama',
#  'Drama',
#  'Western',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Horror',
#  'Crime',
#  'Drama',
#  'Fantasy',
#  'Mystery',
#  'Adventure',
#  'Comedy',
#  'Sci-Fi',
#  'Mystery',
#  'Romance',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Adventure',
#  'Biography',
#  'Drama',
#  'War',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Animation',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Musical',
#  'Crime',
#  'Drama',
#  'Drama',
#  'War',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Romance',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'War',
#  'Drama',
#  'Crime',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Music',
#  'Mystery',
#  'Crime',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Film-Noir',
#  'Mystery',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'War',
#  'Animation',
#  'Drama',
#  'Fantasy',
#  'Romance',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Comedy',
#  'Music',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Documentary',
#  'Biography',
#  'Sport',
#  'Biography',
#  'Drama',
#  'History',
#  'Musical',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Music',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Musical',
#  'Romance',
#  'Animation',
#  'Adventure',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'War',
#  'Adventure',
#  'Comedy',
#  'Fantasy',
#  'Animation',
#  'Drama',
#  'War',
#  'Action',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Drama',
#  'Film-Noir',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Western',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'War',
#  'Comedy',
#  'Music',
#  'Romance',
#  'Drama',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'History',
#  'War',
#  'Drama',
#  'Fantasy',
#  'War',
#  'Drama',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Animation',
#  'Short',
#  'Comedy',
#  'Crime',
#  'Family',
#  'Mystery',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Drama',
#  'Action',
#  'Drama',
#  'History',
#  'Thriller',
#  'War',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Family',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Film-Noir',
#  'Mystery',
#  'Romance',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'War',
#  'Action',
#  'Drama',
#  'War',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Western',
#  'Drama',
#  'Western',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Documentary',
#  'Biography',
#  'Crime',
#  'History',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Drama',
#  'Mystery',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Drama',
#  'War',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Family',
#  'Sport',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'War',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'War',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Film-Noir',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Romance',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Action',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Film-Noir',
#  'Thriller',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Romance',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Sci-Fi',
#  'Drama',
#  'Musical',
#  'Biography',
#  'Drama',
#  'Music',
#  'Drama',
#  'Mystery',
#  'Romance',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'War',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Family',
#  'Comedy',
#  'History',
#  'Adventure',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Thriller',
#  'Western',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Mystery',
#  'Biography',
#  'Drama',
#  'History',
#  'War',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Sport',
#  'Biography',
#  'Crime',
#  'Drama',
#  'History',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Musical',
#  'Romance',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'War',
#  'Comedy',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Sport',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Sport',
#  'Drama',
#  'History',
#  'Action',
#  'Crime',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Sci-Fi',
#  'Drama',
#  'History',
#  'War',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Drama',
#  'Film-Noir',
#  'Mystery',
#  'Romance',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Western',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Action',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'History',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Comedy',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'History',
#  'War',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Crime',
#  'Drama',
#  'History',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Film-Noir',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Music',
#  'Adventure',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Family',
#  'Crime',
#  'Drama',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Comedy',
#  'Fantasy',
#  'Mystery',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Romance',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Horror',
#  'Mystery',
#  'Sci-Fi',
#  'Comedy',
#  'Crime',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'War',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Biography',
#  'Drama',
#  'History',
#  'Drama',
#  'Romance',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'War',
#  'Drama',
#  'War',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Family',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Fantasy',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Music',
#  'Romance',
#  'Action',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Western',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Horror',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Romance',
#  'Drama',
#  'Thriller',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Family',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'History',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  ...]

# %%
# we find the unique genres
# sets make it so only unique values are considered
unique_genres = set(all_genres)
print(len(unique_genres))
# Out:
# 23

# %%
# map to counter how often each genre appears
genre_map = {}

# used AI for this part
for genre in all_genres:
    genre_map[genre] = genre_map.get(genre, 0) + 1

top_5 = sorted(genre_map.items(), key=lambda x: x[1], reverse=True)[:5]

print(f"Top 5 genres: {top_5}")
#movies.head(20)
# Out:
# Top 5 genres: [('Drama', 726), ('Comedy', 289), ('Thriller', 229), ('Adventure', 206), ('Romance', 206)]

# %% [markdown]
# ##### 2. What is the newest movie in the dataset? The oldest?
# ##### Answer:
# ##### Newest: Chak De! India
# ##### Oldest: The Cabinet of Dr. Caligari

# %%
movies.head(5)
# Out:
#    Position                     Title  IMDb Rating  Runtime (mins)  Year  \
# 0         1  The Shawshank Redemption          9.3             142  1994
# 1         2             The Godfather          9.2             175  1972
# 2         3                 12th Fail          8.7             147  2023
# 3         4     The Godfather Part II          9.0             202  1974
# 4         5           The Dark Knight          9.1             152  2008
#
#                            Genres  Num Votes Release Date  \
# 0                           Drama    3127837   10/14/1994
# 1                    Crime, Drama    2182281    3/24/1972
# 2                Biography, Drama     163253   10/27/2023
# 3                    Crime, Drama    1467166   12/18/1974
# 4  Action, Crime, Drama, Thriller    3103433    7/18/2008
#
#               Directors
# 0        Frank Darabont
# 1  Francis Ford Coppola
# 2    Vidhu Vinod Chopra
# 3  Francis Ford Coppola
# 4     Christopher Nolan

# %%
# we convert the date(string format) into a number that we can use
# we had that one NaN value in release date, "errors = "coerce" will ignore it for us
movies["Release Date"] = pd.to_datetime(movies["Release Date"], errors="coerce")
movies.sort_values("Release Date", inplace=True)
# year first, month second, then day
movies.head(5)
# Out:
#      Position                            Title  IMDb Rating  Runtime (mins)  \
# 539       540      The Cabinet of Dr. Caligari          8.0              67
# 150       151                          The Kid          8.2              68
# 566       567  Nosferatu: A Symphony of Horror          7.8              94
# 437       438                     Safety Last!          8.1              74
# 266       267                     Sherlock Jr.          8.1              45
#
#      Year                             Genres  Num Votes Release Date  \
# 539  1920          Horror, Mystery, Thriller      75076   1920-02-27
# 150  1921              Comedy, Drama, Family     143867   1921-02-06
# 566  1922                    Fantasy, Horror     121787   1922-12-19
# 437  1923  Action, Comedy, Romance, Thriller      24457   1923-04-01
# 266  1924            Action, Comedy, Romance      64226   1924-05-11
#
#                         Directors
# 539                  Robert Wiene
# 150               Charles Chaplin
# 566                   F.W. Murnau
# 437  Fred C. Newmeyer, Sam Taylor
# 266                 Buster Keaton

# %%
# finds the smallest and largest values of time, which gives us newest and oldest movies
oldest_date = movies["Release Date"].min()
newest_date = movies["Release Date"].max()

# %%
# now we get the actual movie that corresponds with the date
oldest_movie = movies[movies["Release Date"] == oldest_date]
newest_movie = movies[movies["Release Date"] == newest_date]

print(f"Oldest movie is: {oldest_movie["Title"]} \nNewest movie is: {newest_movie["Title"]}")
# Out:
# Oldest movie is: 539    The Cabinet of Dr. Caligari
# Name: Title, dtype: object
# Newest movie is: 480    Chak De! India
# Name: Title, dtype: object

# %% [markdown]
# ##### 3. What are the top 10 highest-rated movies (by IMDb rating)?

# %%
# gives 10 highest rating movies, their title, and index
movies.sort_values("IMDb Rating", ascending=False)[['Title', 'IMDb Rating']].head(10)
# Out:
#                                              Title  IMDb Rating
# 734               The Godfather Trilogy: 1901-1980          9.3
# 0                         The Shawshank Redemption          9.3
# 1                                    The Godfather          9.2
# 710                                The Chaos Class          9.2
# 4                                  The Dark Knight          9.1
# 5                                 Schindler's List          9.0
# 37                          CM101MMXI Fundamentals          9.0
# 8                                     12 Angry Men          9.0
# 3                            The Godfather Part II          9.0
# 6    The Lord of the Rings: The Return of the King          9.0

# %% [markdown]
# ##### 4. What is the distribution of IMDb ratings (mean, median, standard deviation)?

# %%
# this gives the mean and standard deviation
# movies["IMDb Rating"].describe()

# we can also do this
rating_mean = movies["IMDb Rating"].mean()
rating_median = movies["IMDb Rating"].median()
rating_std = movies["IMDb Rating"].std()

print(f"Mean: {rating_mean:.2f}")
print(f"Median: {rating_median:.2f}")
print(f"Standard Deviation: {rating_std:.4f}")
# Out:
# Mean: 7.84
# Median: 7.90
# Standard Deviation: 0.4678

# %% [markdown]
# ##### 5. How do average IMDb ratings vary by genre?

# %%
# done with help from AI and google
# we split the genres into different lists
movies_exploded = movies.copy()
# str.split converts the string into multiple genres (since a movie can have more than one)
movies_exploded['Genres'] = movies_exploded['Genres'].str.split(',')
# we turn the lists into rows
movies_exploded = movies_exploded.explode('Genres')
# cleans whitespace
movies_exploded['Genres'] = movies_exploded['Genres'].str.strip()
# groups/aggregates the data
avg_ratings = movies_exploded.groupby('Genres')['IMDb Rating'].mean()

# %%
# our result
avg_ratings_by_genre = movies_exploded.groupby('Genres')['IMDb Rating'].mean().sort_values(ascending=False)
print(avg_ratings_by_genre)
# Out:
# Genres
# Documentary    8.027273
# Film-Noir      7.988889
# War            7.952500
# Animation      7.940299
# Sport          7.916000
# Biography      7.893069
# Mystery        7.892500
# Crime          7.883417
# History        7.877049
# Drama          7.873416
# Short          7.860000
# Family         7.853409
# Fantasy        7.850000
# Western        7.840000
# Thriller       7.824454
# Adventure      7.821359
# Sci-Fi         7.790833
# Action         7.773370
# Music          7.758824
# Musical        7.758537
# Romance        7.715534
# Comedy         7.704844
# Horror         7.680488
# Name: IMDb Rating, dtype: float64

# %% [markdown]
# ##### 6. What director has the most movies in the dataset?

# %%
# similar to the solution for problem 5
# split multiple directors and explode into separate rows
movies_directors = movies.copy()
movies_directors['Directors'] = movies_directors['Directors'].str.split(',')
movies_directors = movies_directors.explode('Directors')
movies_directors['Directors'] = movies_directors['Directors'].str.strip()  # removes whitespaces

# %%
director_counts = movies_directors['Directors'].value_counts()
director_counts.head(10)
# Out:
# Directors
# Alfred Hitchcock     13
# Steven Spielberg     11
# Akira Kurosawa       10
# Stanley Kubrick      10
# Ethan Coen           10
# Joel Coen            10
# Christopher Nolan     9
# Billy Wilder          9
# Martin Scorsese       9
# Peter Jackson         9
# Name: count, dtype: int64

# %% [markdown]
# ##### 9. Average Runtime per year (if applicable)

# %%
movies.head()
# Out:
#      Position                            Title  IMDb Rating  Runtime (mins)  \
# 539       540      The Cabinet of Dr. Caligari          8.0              67
# 150       151                          The Kid          8.2              68
# 566       567  Nosferatu: A Symphony of Horror          7.8              94
# 437       438                     Safety Last!          8.1              74
# 266       267                     Sherlock Jr.          8.1              45
#
#      Year                             Genres  Num Votes Release Date  \
# 539  1920          Horror, Mystery, Thriller      75076   1920-02-27
# 150  1921              Comedy, Drama, Family     143867   1921-02-06
# 566  1922                    Fantasy, Horror     121787   1922-12-19
# 437  1923  Action, Comedy, Romance, Thriller      24457   1923-04-01
# 266  1924            Action, Comedy, Romance      64226   1924-05-11
#
#                         Directors
# 539                  Robert Wiene
# 150               Charles Chaplin
# 566                   F.W. Murnau
# 437  Fred C. Newmeyer, Sam Taylor
# 266                 Buster Keaton

# %%
# movies['Runtime (mins)'] = pd.to_numeric(movies["Runtime (mins)"])
# don't need to convert actually

# %%
avg_runtime_per_year = movies.groupby('Year')['Runtime (mins)'].mean().sort_index()

# sees all values, I think it gets cut off anyways because of output limit in jupyter notebooks
pd.set_option('display.max_rows', None)
print(avg_runtime_per_year)
# Out:
# Year
# 1920     67.000000
# 1921     68.000000
# 1922     94.000000
# 1923     74.000000
# 1924     45.000000
# 1925    104.000000
# 1926     78.000000
# 1927    123.500000
# 1928     93.000000
# 1929     16.000000
# 1930    152.000000
# 1931     85.333333
# 1933     84.500000
# 1934     98.000000
# 1935     85.666667
# 1936     90.500000
# 1937     98.000000
# 1938    100.000000
# 1939    135.000000
# 1940    118.666667
# 1941    103.000000
# 1942     89.500000
# 1943     91.500000
# 1944    103.250000
# 1945    125.333333
# 1946    121.166667
# 1947     96.500000
# 1948    112.600000
# 1949    108.000000
# 1950    104.000000
# 1951    102.833333
# 1952    109.800000
# 1953    129.800000
# 1954    125.125000
# 1955    106.500000
# 1956    130.250000
# 1957    107.222222
# 1958    116.333333
# 1959    145.000000
# 1960    135.857143
# 1961    138.200000
# 1962    132.875000
# 1963    132.833333
# 1964    122.600000
# 1965    132.000000
# 1966    121.142857
# 1967    106.875000
# 1968    139.600000
# 1969    121.250000
# 1970    142.333333
# 1971    131.875000
# 1972    130.000000
# 1973    112.428571
# 1974    128.800000
# 1975    126.000000
# 1976    118.777778
# 1977    106.400000
# 1978    120.800000
# 1979    124.333333
# 1980    118.250000
# 1981    126.200000
# 1982    126.750000
# 1983    131.333333
# 1984    135.000000
# 1985    116.333333
# 1986    113.500000
# 1987    111.928571
# 1988    130.076923
# 1989    104.666667
# 1990    125.636364
# 1991    133.333333
# 1992    137.150000
# 1993    129.217391
# 1994    111.636364
# 1995    110.342105
# 1996    119.900000
# 1997    121.166667
# 1998    114.000000
# 1999    120.076923
# 2000    121.421053
# 2001    130.650000
# 2002    123.380952
# 2003    143.500000
# 2004    122.727273
# 2005    131.416667
# 2006    125.500000
# 2007    124.875000
# 2008    118.631579
# 2009    121.136364
# 2010    117.944444
# 2011    129.181818
# 2012    143.466667
# 2013    138.200000
# 2014    130.523810
# 2015    133.700000
# 2016    127.000000
# 2017    127.333333
# 2018    133.000000
# 2019    137.714286
# 2020    121.333333
# 2021    158.857143
# 2022    148.333333
# 2023    150.142857
# 2024    136.333333
# Name: Runtime (mins), dtype: float64

# %% [markdown]
# ##### 10. Shortest movie for each genre (if applicable)

# %%
# # find shortest movie per genre
# # could not understand how to only have 1 genre
# shortest_per_genre = movies_exploded.loc[movies_exploded.groupby('Genres')['Runtime (mins)'].idxmin()]
# shortest_per_genre = shortest_per_genre[['Genres', 'Title', 'Runtime (mins)']].sort_values('Runtime (mins)')
# print(shortest_per_genre)

# AI's code, could not find a solution without repetition of movies
# find shortest movie per genre
shortest_per_genre = movies_exploded.loc[movies_exploded.groupby('Genres')['Runtime (mins)'].idxmin()]
# Remove duplicate (genre, title) pairs if any
shortest_per_genre = shortest_per_genre[['Genres', 'Title', 'Runtime (mins)']].drop_duplicates().sort_values('Runtime (mins)')
print(shortest_per_genre)

type(shortest_per_genre)
# Out:
#           Genres                                    Title  Runtime (mins)
# 882       Horror                         Un chien andalou              16
# 882        Short                         Un chien andalou              16
# 882      Fantasy                         Un chien andalou              16
# 668        Short               T2 3-D: Battle Across Time              21
# 668       Sci-Fi               T2 3-D: Battle Across Time              21
# 668       Action               T2 3-D: Battle Across Time              21
# 779        Short        Wallace & Gromit: A Grand Day Out              23
# 779    Animation        Wallace & Gromit: A Grand Day Out              23
# 779       Sci-Fi        Wallace & Gromit: A Grand Day Out              23
# 779    Adventure        Wallace & Gromit: A Grand Day Out              23
# 779       Comedy        Wallace & Gromit: A Grand Day Out              23
# 779       Family        Wallace & Gromit: A Grand Day Out              23
# 854       Family                A Charlie Brown Christmas              25
# 854       Comedy                A Charlie Brown Christmas              25
# 854        Drama                A Charlie Brown Christmas              25
# 854        Music                A Charlie Brown Christmas              25
# 854    Animation                A Charlie Brown Christmas              25
# 181       Comedy          How the Grinch Stole Christmas!              26
# 181       Family          How the Grinch Stole Christmas!              26
# 181      Musical          How the Grinch Stole Christmas!              26
# 181    Animation          How the Grinch Stole Christmas!              26
# 181      Fantasy          How the Grinch Stole Christmas!              26
# 132      Mystery     Wallace & Gromit: The Wrong Trousers              30
# 132       Sci-Fi     Wallace & Gromit: The Wrong Trousers              30
# 132    Animation     Wallace & Gromit: The Wrong Trousers              30
# 132        Short     Wallace & Gromit: The Wrong Trousers              30
# 132       Comedy     Wallace & Gromit: The Wrong Trousers              30
# 132       Family     Wallace & Gromit: The Wrong Trousers              30
# 132        Crime     Wallace & Gromit: The Wrong Trousers              30
# 266       Comedy                             Sherlock Jr.              45
# 266      Romance                             Sherlock Jr.              45
# 266       Action                             Sherlock Jr.              45
# 892  Documentary     Playboy: The Best of Pamela Anderson              54
# 603        Drama                      Battleship Potemkin              66
# 603     Thriller                      Battleship Potemkin              66
# 603      History                      Battleship Potemkin              66
# 603          War                      Battleship Potemkin              66
# 533        Drama                      The Ox-Bow Incident              75
# 533      Western                      The Ox-Bow Incident              75
# 471    Biography  The King of Kong: A Fistful of Quarters              79
# 471  Documentary  The King of Kong: A Fistful of Quarters              79
# 471        Sport  The King of Kong: A Fistful of Quarters              79
# 407        Drama                              The Killing              84
# 407        Crime                              The Killing              84
# 407     Thriller                              The Killing              84
# 407    Film-Noir                              The Killing              84
# pandas.core.frame.DataFrame

# %%
movies.head(5)
# Out:
#      Position                            Title  IMDb Rating  Runtime (mins)  \
# 539       540      The Cabinet of Dr. Caligari          8.0              67
# 150       151                          The Kid          8.2              68
# 566       567  Nosferatu: A Symphony of Horror          7.8              94
# 437       438                     Safety Last!          8.1              74
# 266       267                     Sherlock Jr.          8.1              45
#
#      Year                             Genres  Num Votes Release Date  \
# 539  1920          Horror, Mystery, Thriller      75076   1920-02-27
# 150  1921              Comedy, Drama, Family     143867   1921-02-06
# 566  1922                    Fantasy, Horror     121787   1922-12-19
# 437  1923  Action, Comedy, Romance, Thriller      24457   1923-04-01
# 266  1924            Action, Comedy, Romance      64226   1924-05-11
#
#                         Directors
# 539                  Robert Wiene
# 150               Charles Chaplin
# 566                   F.W. Murnau
# 437  Fred C. Newmeyer, Sam Taylor
# 266                 Buster Keaton

# %% [markdown]
# #####

# %%
# # find longest movie per genre
# # .idmax() returns the index label of where the max value in a series occurs
# longest_per_genre = movies_exploded.loc[movies_exploded.groupby('Genres')['Runtime (mins)'].idxmax()]
# longest_per_genre = longest_per_genre[['Genres', 'Title', 'Runtime (mins)']].sort_values('Runtime (mins)', ascending=False)
# print(longest_per_genre)

# find longest movie per genre
longest_per_genre = movies_exploded.loc[movies_exploded.groupby('Genres')['Runtime (mins)'].idxmax()]
# Remove duplicate (genre, title) pairs if any
longest_per_genre = longest_per_genre[['Genres', 'Title', 'Runtime (mins)']].drop_duplicates().sort_values('Runtime (mins)', ascending=False)
print(longest_per_genre)
# Out:
#           Genres                                Title  Runtime (mins)
# 734        Drama     The Godfather Trilogy: 1901-1980             583
# 734     Thriller     The Godfather Trilogy: 1901-1980             583
# 734        Crime     The Godfather Trilogy: 1901-1980             583
# 711      Romance                    The Best of Youth             374
# 711        Drama                    The Best of Youth             374
# 411       Comedy                   Gangs of Wasseypur             321
# 411     Thriller                   Gangs of Wasseypur             321
# 411       Action                   Gangs of Wasseypur             321
# 411        Crime                   Gangs of Wasseypur             321
# 411        Drama                   Gangs of Wasseypur             321
# 834       Action           Until the End of the World             287
# 834        Drama           Until the End of the World             287
# 834     Thriller           Until the End of the World             287
# 834       Sci-Fi           Until the End of the World             287
# 709        Drama                           Gettysburg             254
# 709      History                           Gettysburg             254
# 709          War                           Gettysburg             254
# 277       Sci-Fi         Zack Snyder's Justice League             242
# 277    Adventure         Zack Snyder's Justice League             242
# 277       Action         Zack Snyder's Justice League             242
# 277      Fantasy         Zack Snyder's Justice League             242
# 72     Biography                   Lawrence of Arabia             227
# 72         Drama                   Lawrence of Arabia             227
# 72     Adventure                   Lawrence of Arabia             227
# 72           War                   Lawrence of Arabia             227
# 408      Musical    Lagaan: Once Upon a Time in India             224
# 408        Sport    Lagaan: Once Upon a Time in India             224
# 408        Drama    Lagaan: Once Upon a Time in India             224
# 972       Family                 The Ten Commandments             220
# 972      History                 The Ten Commandments             220
# 972        Drama                 The Ten Commandments             220
# 972    Adventure                 The Ten Commandments             220
# 267     Thriller                           Grindhouse             191
# 267       Horror                           Grindhouse             191
# 66         Drama                       The Green Mile             189
# 66       Fantasy                       The Green Mile             189
# 66       Mystery                       The Green Mile             189
# 66         Crime                       The Green Mile             189
# 510    Adventure                   Dances with Wolves             181
# 510        Drama                   Dances with Wolves             181
# 510      Western                   Dances with Wolves             181
# 883        Drama                Farewell My Concubine             171
# 883      Romance                Farewell My Concubine             171
# 883        Music                Farewell My Concubine             171
# 844  Documentary                          Hoop Dreams             170
# 844        Drama                          Hoop Dreams             170
# 844        Sport                          Hoop Dreams             170
# 19        Action  Spider-Man: Across the Spider-Verse             140
# 19     Adventure  Spider-Man: Across the Spider-Verse             140
# 19        Family  Spider-Man: Across the Spider-Verse             140
# 19       Fantasy  Spider-Man: Across the Spider-Verse             140
# 19     Animation  Spider-Man: Across the Spider-Verse             140
# 19        Sci-Fi  Spider-Man: Across the Spider-Verse             140
# 249    Film-Noir                        The Big Sleep             114
# 249        Crime                        The Big Sleep             114
# 249        Drama                        The Big Sleep             114
# 249      Mystery                        The Big Sleep             114
# 249     Thriller                        The Big Sleep             114
# 567    Animation      Wallace & Gromit: A Close Shave              31
# 567        Short      Wallace & Gromit: A Close Shave              31
# 567       Family      Wallace & Gromit: A Close Shave              31
# 567        Crime      Wallace & Gromit: A Close Shave              31
# 567       Comedy      Wallace & Gromit: A Close Shave              31
# 567      Mystery      Wallace & Gromit: A Close Shave              31
