# %% [markdown]
# # Jupyter Notebook Basics Exercise

# %% [markdown]
# ## Part 1

# %% [markdown]
# Run the following cell:

# %%
u = "Cnrt!Yuddi!"
l = 'ogas o i t!'
"".join(i + j for i, j in zip(u, l))
# Out:
# 'Congrats! You did it!!'

# %%
# Notes for Stanley:
# zip() creates a list of tuples from pairing elements of two data structures, why tuples though?

names = ["Stanley", "Lisa", "Dwight", "Alice"]
ages = [22, 28, 45, 103]

zipped = zip(names, ages)
# print(zipped[0]) or print(zipped[0][0] won't work
# Need to iterate thorugh each tuple to see the values like this
for item in zipped:
    print(item)
# Looks useful for creating new tables
# Out:
# ('Stanley', 22)
# ('Lisa', 28)
# ('Dwight', 45)
# ('Alice', 103)

# %% [markdown]
# If you were unfamiliar with the zip() function, see if you can use the documentation below to understand what it does, it's syntax, and output: <br/>
# [Python Documentation](https://docs.python.org/3/index.html)

# %% [markdown]
# <details>
# <summary> <b>Need a hint on where to go?</b> </summary>
#   From the documentation link above, navigate to: Library reference -> Built-in Functions -> zip()
# </details>

# %% [markdown]
# ## Part 2

# %%
# Write a python function to replace <YOURNAME> with whatever name is supplied to the function
"Wow, <YOURNAME> is the most amazing person on this planet"
# Out:
# 'Wow, <YOURNAME> is the most amazing person on this planet'

# %%
# Show an example calling your function with your name as the argument
# Function and variable assigned with my name
name = "Stanley"
def compliment(name):
    return f"Wow, {name} is the most amazing person on this planet"

# Calls function
compliment(name)
# Out:
# 'Wow, Stanley is the most amazing person on this planet'

# %% [markdown]
# ## Part 3
# Create 3 new empty cells directly below this cell.

# %% [markdown]
# ## Part 4

# %%
#Run this cell!
print("chicken nuggetz")
# Out:
# chicken nuggetz

# %% [markdown]
# ## Part 5
# These cells are out of order! Swap their order and then run them both!

# %%
number = 42

# %%
number * number
# Out:
# 1764

# %% [markdown]
# ## Part 6

# %%
### Make this cell a python cell and run it (it's markdown right now)

"supercalifragilisticexpialidocious" * 20
# Out:
# '...'

# %% [markdown]
# ## Part 7

# %%
# This cell is supposed to print the integers from 9 down to 1 (but it doesnt!)
# 1. Run this cell which results in an INFINITE LOOP
# 2. Interrupt the infinite loop
# 3. Fix the code so that it prints 9,8,7,6,5,4,3,2,1 and run the cell again!

num = 10 
while num > 1:
    num-=1
    print(num)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ## Part 8
# Shutdown this notebook
